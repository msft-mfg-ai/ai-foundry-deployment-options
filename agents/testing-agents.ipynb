# %% [markdown]
# # Testing Agents in AI Foundry
# This notebook creates and runs an agent from AI Foundry
#
# Best way to set it up is with [uv](https://docs.astral.sh/uv/)
#
# 1. in `agents` directory run `uv sync` (if python is missing, install it using `uv python install`)
# 2. in VSCode press [Ctrl+Shift+P] and select `Python: Select Interpreter`, choose the one from `agents` directory: `./agents/.venv/bin/python3.xx`

# %%
# Install required packages

! pip install requests "semantic-kernel[azure]>=1.35.2" jsonref azure-identity

# %% [markdown]
# ## Step 2
# Create Project client

# %%
from datetime import date
import os
from semantic_kernel.contents.chat_message_content import ChatMessageContent
from semantic_kernel.contents import FunctionCallContent, FunctionResultContent
from semantic_kernel.agents import (
    AzureAIAgent,
    AzureAIAgentThread,
    AzureAIAgentSettings,
)
from azure.identity import DefaultAzureCredential, AzureDeveloperCliCredential
from azure.ai.agents.models import (
    OpenApiTool,
    OpenApiAnonymousAuthDetails,
    McpTool,
    ToolDefinition,
)
import jsonref
from dotenv import load_dotenv

# Load environment variables from the .env file
load_dotenv(override=True)

endpoint = os.environ.get("AZURE_AI_FOUNDRY_CONNECTION_STRING")
deployment_name = os.environ.get("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME")
api_version = os.environ.get("AZURE_OPENAI_API_VERSION", None)
tenant_id = os.environ.get("AZURE_TENANT_ID", None)

ai_agent_settings = AzureAIAgentSettings(
    endpoint=endpoint,
    model_deployment_name=deployment_name,
    api_version=api_version,
)
print(ai_agent_settings)

creds = (
    AzureDeveloperCliCredential(tenant_id=tenant_id)
    if os.environ.get("USE_AZURE_DEV_CLI") == "true"
    else DefaultAzureCredential()
)
# uncomment to test token aquisition
# token_test  = creds.get_token("https://ai.azure.com")
# print(f"Token for https://ai.azure.com: {token_test.token[:10]}...")

client = AzureAIAgent.create_client(
    credential=creds,
    endpoint=ai_agent_settings.endpoint,
    api_version=ai_agent_settings.api_version,
)

# List agents
print("\n --- Agents ---")
async for agent in client.agents.list_agents():
    print(
        f"Agent ID: {agent.id}, Name: {agent.name}, Description: {agent.description}, Deployment Name: {agent.model}"
    )

print("\n --- Connections ---")
# List connections
async for connection in client.connections.list():
    print(
        f"Connection ID: {connection.id}, Name: {connection.name}, Type: {connection.type} Default: {connection.is_default}"
    )
# Out:
# env_file_path=None env_file_encoding='utf-8' model_deployment_name='test-gpt-4.1-mini' endpoint='https://ai-foundry-vy77ois7p2ego.services.ai.azure.com/api/projects/ai-project-1' agent_id=None bing_connection_id=None azure_ai_search_connection_id=None azure_ai_search_index_name=None api_version=None deep_research_model=None
#
#  --- Agents ---
# Agent ID: asst_v8Y7yeAUGuWo0ITZlXltJxur, Name: Jonny_Weather_openapi, Description: None, Deployment Name: gpt-4.1-mini
# Agent ID: asst_SrdAi6bbzwdFMNqpNsr4jxNx, Name: Jonny_Weather_mcp, Description: None, Deployment Name: gpt-4.1-mini
#
#  --- Connections ---
# Connection ID: /subscriptions/0721e282-2773-4021-af16-e00641ed5e36/resourceGroups/rg-foundry-external-pe/providers/Microsoft.CognitiveServices/accounts/ai-foundry-vy77ois7p2ego/projects/ai-project-1/connections/aiConnection-foundry-for-ai-foundry-vy77ois7p2ego, Name: aiConnection-foundry-for-ai-foundry-vy77ois7p2ego, Type: AIServices Default: True
# Connection ID: /subscriptions/0721e282-2773-4021-af16-e00641ed5e36/resourceGroups/rg-foundry-external-pe/providers/Microsoft.CognitiveServices/accounts/ai-foundry-vy77ois7p2ego/projects/ai-project-1/connections/projstoragevy77ois7p2ego-for-ai-project-1, Name: projstoragevy77ois7p2ego-for-ai-project-1, Type: ConnectionType.AZURE_STORAGE_ACCOUNT Default: False
# Connection ID: /subscriptions/0721e282-2773-4021-af16-e00641ed5e36/resourceGroups/rg-foundry-external-pe/providers/Microsoft.CognitiveServices/accounts/ai-foundry-vy77ois7p2ego/projects/ai-project-1/connections/project-search-vy77ois7p2ego-for-ai-project-1, Name: project-search-vy77ois7p2ego-for-ai-project-1, Type: ConnectionType.AZURE_AI_SEARCH Default: False
# Connection ID: /subscriptions/0721e282-2773-4021-af16-e00641ed5e36/resourceGroups/rg-foundry-external-pe/providers/Microsoft.CognitiveServices/accounts/ai-foundry-vy77ois7p2ego/projects/ai-project-1/connections/applicationInsights-for-ai-project-1, Name: applicationInsights-for-ai-project-1, Type: ConnectionType.APPLICATION_INSIGHTS Default: False
# Connection ID: /subscriptions/0721e282-2773-4021-af16-e00641ed5e36/resourceGroups/rg-foundry-external-pe/providers/Microsoft.CognitiveServices/accounts/ai-foundry-vy77ois7p2ego/projects/ai-project-1/connections/aiConnection-project-for-ai-project-1, Name: aiConnection-project-for-ai-project-1, Type: AIServices Default: False
# Connection ID: /subscriptions/0721e282-2773-4021-af16-e00641ed5e36/resourceGroups/rg-foundry-external-pe/providers/Microsoft.CognitiveServices/accounts/ai-foundry-vy77ois7p2ego/projects/ai-project-1/connections/project-cosmosdb-vy77ois7p2ego-for-ai-project-1, Name: project-cosmosdb-vy77ois7p2ego-for-ai-project-1, Type: CosmosDb Default: False

# %% [markdown]
# ### Prepare Tools

# %%
mcp_server_url = os.environ.get("MCP_SERVER_URL", None)
openapi_server_url = os.environ.get("OPENAPI_SERVER_URL", None)
mcp_server_label = os.environ.get("MCP_SERVER_LABEL", "tool")

mcp_tools: list[ToolDefinition] = []
openapi_tools: list[ToolDefinition] = []
mcp_tool: McpTool | None = None

if mcp_server_url:
    mcp_tool = McpTool(
        server_label=mcp_server_label,
        server_url=mcp_server_url,
        allowed_tools=[],  # Optional: specify allowed tools
    )
    mcp_tool.set_approval_mode("never")

    print(
        f"Using MCP Tool with server URL: {mcp_server_url} and label: {mcp_server_label}"
    )
    mcp_tools = mcp_tools + mcp_tool.definitions

    # add same tool again with different label
    mcp_tool_2 = McpTool(
        server_label="current_weather",
        server_url=mcp_server_url,
        allowed_tools=[],  # Optional: specify allowed tools
    )
    mcp_tool_2.set_approval_mode("never")
    mcp_tools = mcp_tools + mcp_tool_2.definitions


if openapi_server_url:
    with open("weather.json", "r") as f:
        openapi_weather = jsonref.loads(f.read())
        openapi_weather["servers"] = [{"url": openapi_server_url}]

    openapi_tool = OpenApiTool(
        name="WeatherAPI",
        spec=openapi_weather,
        auth=OpenApiAnonymousAuthDetails(),
        description="Retrieve weather information for a location",
        # allowed_tools=[],  # Optional: specify allowed tools
    )
    print(f"Using OpenAPI Tool with server URL: {openapi_server_url}")
    openapi_tools = openapi_tools + openapi_tool.definitions
# Out:
# Using MCP Tool with server URL: https://sample-mcp-qczp34j2qg7pk.ashyocean-7ea49412.westus.azurecontainerapps.io/mcp and label: tools
# Using OpenAPI Tool with server URL: https://aca-openapi-qczp34j2qg7pk.ashyocean-7ea49412.westus.azurecontainerapps.io

# %% [markdown]
# ### Create Agents

# %%
user_message = (
    "You are a reliable, funny and amusing weather forecaster named Jonny Weather. "
    "You provide weather forecasts in a humorous and engaging manner. "
    "You like to use puns and jokes to make the weather more entertaining. "
    "You love to use emojis to make your forecasts more colorful and fun. "
    "You are very knowledgeable about the weather, history of forecasting, and the science behind it. "
    "You've been doing this for a long time and have a lot of experience. Love to talk about your adventures in the field."
    "You always use the weather tools provided to you, never make stuff up. "
    "You've been living in Galway, Ireland for the past 20 years, you've seen it all and done it all. ☔️🌈"
    "\n"
    "## Rules\n"
    "* Always provide a weather forecast for today and tomorrow."
    "* Use emojis to make your forecasts more colorful and fun."
    "* Use tables to present weather."
    "* If you don't know the answer, say 'I don't know' or 'I don't have that information'."
)
# agent_instructions = "You're a helpful agent"


async def create_agent(
    agent_name: str, agent_instructions: str, tools: list[ToolDefinition]
) -> AzureAIAgent:

    agent_definition = None
    async for agent in client.agents.list_agents():
        if agent.name == agent_name and agent_definition is None:
            agent_definition = agent
            break

    if agent_definition:
        print(
            f"Found existing agent with ID: {agent_definition.id} and name: {agent_definition.name}"
        )
        agent_definition = await client.agents.update_agent(
            agent_id=agent_definition.id,
            instructions=agent_instructions,
            model=ai_agent_settings.model_deployment_name,
            tools=tools,
            temperature=0.2,
        )
        print(
            f"Updated agent with id {agent_definition.id} name: {agent_name} with model {ai_agent_settings.model_deployment_name}"
        )
    else:
        agent_definition = await client.agents.create_agent(
            model=ai_agent_settings.model_deployment_name,
            name=agent_name,
            instructions=agent_instructions,
            tools=tools,
            temperature=0.2,
        )
        print(
            f"Created agent with id {agent_definition.id} name: {agent_name} with model {ai_agent_settings.model_deployment_name}"
        )

    agent = AzureAIAgent(
        client=client,
        definition=agent_definition,
    )
    return agent


agent_name_mcp = "Jonny_Weather_mcp"
agent_name_openapi = "Jonny_Weather_openapi"
agent_name_logicapp = "Jonny_Weather_logicapp"

mcp_agent = await create_agent(
    agent_name=agent_name_mcp, agent_instructions=user_message, tools=mcp_tools
)

openapi_agent = await create_agent(
    agent_name=agent_name_openapi, agent_instructions=user_message, tools=openapi_tools
)
# Out:
# Found existing agent with ID: asst_SrdAi6bbzwdFMNqpNsr4jxNx and name: Jonny_Weather_mcp
# Updated agent with id asst_SrdAi6bbzwdFMNqpNsr4jxNx name: Jonny_Weather_mcp with model test-gpt-4.1-mini
# Found existing agent with ID: asst_v8Y7yeAUGuWo0ITZlXltJxur and name: Jonny_Weather_openapi
# Updated agent with id asst_v8Y7yeAUGuWo0ITZlXltJxur name: Jonny_Weather_openapi with model test-gpt-4.1-mini

# %% [markdown]
# ### Use the agent

# %%
user_message = "What's the weather in NYC"


async def on_intermediate_message(agent_response: ChatMessageContent):
    print(f"Intermediate response from MCP Agent: {agent_response}")
    for item in agent_response.items or []:
        if isinstance(item, FunctionResultContent):
            print(f"Function Result:> {item.result} for function: {item.name}")
        elif isinstance(item, FunctionCallContent):
            print(f"Function Call:> {item.name} with arguments: {item.arguments}")
        else:
            print(f"{item}")


async def test_mcp_foundry_agent():
    print("--------------------- Invoking MCP Agent using AI FOUNDRY SDK")
    try:
        thread = await client.agents.threads.create()
        message = await client.agents.messages.create(
            thread_id=thread.id,
            role="user",
            content=user_message,
        )
        run = await client.agents.runs.create_and_process(
            thread_id=thread.id,
            agent_id=mcp_agent.id,
            tool_resources=mcp_tool.resources if mcp_tool else None,
        )

        print(f"Run finished with status: {run.status}")

        if run.status == "failed":
            print(f"Run failed: {run.last_error}")

        # Retrieve the steps taken during the run for analysis
        run_steps = client.agents.run_steps.list(thread_id=thread.id, run_id=run.id)

        # Loop through each step to display information
        async for step in run_steps:
            print(f"Step {step['id']} status: {step['status']}")

            # Fetch and log all messages
            messages = client.agents.messages.list(thread_id=thread.id)
            async for message in messages:
                print(f"Role: {message.role}, Content: {message.content}")

            tool_calls = step.get("step_details", {}).get("tool_calls", [])
            for call in tool_calls:
                print(f"  Tool Call ID: {call.get('id')}")
                print(
                    f"  Type: {call.get('type')} - server_label: {call.get('server_label')} - name: {call.get('name')} with output: {call.get('output')}"
                )
                function_details = call.get("function", {})
                if function_details:
                    print(f"  Function name: {function_details.get('name')}")
                    print(f" function output: {function_details.get('output')}")

            print()

    except Exception as e:
        print(f"Error invoking MCP Agent: {e}")


async def test_mcp_sk_agent():
    print(
        f"--------------------- Invoking MCP Agent {mcp_agent.id} using Semantic Kernel SDK"
    )
    try:
        if mcp_tool and mcp_agent:
            mcp_tool.set_approval_mode("never")
            thread = AzureAIAgentThread(client=client)
            async for agent_response in mcp_agent.invoke(
                messages=user_message,
                thread=thread,
                additional_instructions="Today is " + date.today().strftime("%Y-%m-%d"),
                tools=mcp_tool.resources,
                on_intermediate_message=on_intermediate_message,
            ):
                print(f"MCP Agent: {agent_response}")
                thread = agent_response.thread
        else:
            print("MCP Agent or tool not available")
    except Exception as e:
        print(f"Error invoking MCP Agent: {e}")


async def test_openapi_agent():
    print("--------------------- Invoking OPEN API Agent using Semantic Kernel SDK")
    try:
        if openapi_agent:
            thread = AzureAIAgentThread(client=client)
            async for agent_response in openapi_agent.invoke(
                messages=user_message,
                thread=thread,
                additional_instructions="Today is " + date.today().strftime("%Y-%m-%d"),
            ):
                print(f"OpenAPI Agent: {agent_response}")
        else:
            print("OpenAPI Agent not available")
    except Exception as e:
        print(f"Error invoking OpenAPI Agent: {e}")


# Run the async function
# await test_mcp_foundry_agent()
await test_mcp_sk_agent()
# await test_openapi_agent()
# Out:
# --------------------- Invoking MCP Agent asst_SrdAi6bbzwdFMNqpNsr4jxNx using Semantic Kernel SDK
# Error invoking MCP Agent: Run failed with status: `RunStatus.FAILED` for agent `Jonny_Weather_mcp` and thread `thread_r8KPu7INwGqGHK57HihDXkIH` with error: MCP Connector error. Http status: 424, error details: Error retrieving tool list from MCP server: 'tools'. Http status code: 424 (Failed Dependency) and incomplete details reason: None

# %%
codex_tool = McpTool(
    server_label="codex",
    server_url="https://gitmcp.io/openai/codex",
)
codex_tool.set_approval_mode("never")
codex_tools: list[ToolDefinition] = [] + codex_tool.definitions

codex_agent = await create_agent(
    agent_name="Codex-Agent",
    agent_instructions="you are a helpful assistant that can answer questions about the codebase",
    tools=codex_tools,
)

codex_thread = AzureAIAgentThread(client=client)
async for agent_response in codex_agent.invoke(
    messages="summarize the code in the repository I pointed the MCP tool to",
    thread=codex_thread,
    additional_instructions="Today is " + date.today().strftime("%Y-%m-%d"),
    tools=codex_tool.resources,
    on_intermediate_message=on_intermediate_message,
):
    print(f"Codex Agent: {agent_response}")
    codex_thread = agent_response.thread
# Out:
# Created agent with id asst_Kw5flSEbJzX7sO75VGht3fHt name: Codex-Agent with model test-gpt-4.1-mini
# Intermediate response from MCP Agent:
# Function Call:> fetch_codex_documentation with arguments: {}
# Intermediate response from MCP Agent:
# Function Result:> # openai/codex/docs Documentation
# Below is a structured llms.txt index of Markdown files extracted from the /docs folder. Each entry contains a link to the raw markdown on GitHub for further documentation details.
#
#
# ## Root Files
#
#
#
# - [CLA.md](https://raw.githubusercontent.com/openai/codex/main/docs/CLA.md): OpenAI Codex Individual Contributor License Agreement
# The OpenAI Codex Individual Contributor License Agreement (CLA) is a legal document that outlines the terms and conditions for contributing to the OpenAI Codex CLI project. By commenting "I have read the CLA Document and I hereby sign the CLA" on a Pull Request, contributors agree to grant OpenAI and its recipients a perpetual, worldwide, non-exclusive license to reproduce, prepare derivative works, and distribute their contributions. The agreement covers definitions, copyright license, patent license, representations, and miscellaneous terms. It is governed by the laws of the State of California, USA.
#
# To contribute to the project, individuals can comment on a Pull Request with the specified text. No code examples are provided in the document.
#
# Additional information:
# The document is based on the Apache Software Foundation Individual CLA v 2.2.
#
# CODE EXAMPLES:
# ```markdown
# By commenting **“I have read the CLA Document and I hereby sign the CLA”**
# on a Pull Request, **you (“Contributor”) agree to the following terms** for any
# past and future “Contributions” submitted to the **OpenAI Codex CLI project
# (the “Project”)**.
# ```
#
# KEY TECHNICAL TERMS/TOPICS:
# 1. Individual Contributor License Agreement (CLA)
# 2. OpenAI Codex CLI project
# 3. Contribution
# 4. Copyright License
# 5. Patent License
# 6. Representations
# 7. Perpetual, worldwide, non-exclusive license
# 8. Royalty-free, irrevocable license
# 9. State of California, USA (governing law)
# 10. Apache Software Foundation Individual CLA v 2.2
#
#
# - [agents_md.md](https://raw.githubusercontent.com/openai/codex/main/docs/agents_md.md): AGENTS.md Documentation and Configuration
# The AGENTS.md document provides guidance on the configuration and behavior of agents in the Codex system. When the `child_agents_md` feature flag is enabled in the `config.toml` file, Codex appends additional guidance about AGENTS.md scope and precedence to the user instructions message. This message is emitted even when no AGENTS.md is present. The document explains how to configure and use AGENTS.md, including the effects of enabling the `child_agents_md` feature flag.
#
# No code examples are present in this document.
#
# KEY TERMS:
# 1. AGENTS.md
# 2. child_agents_md
# 3. feature flag
# 4. config.toml
# 5. Codex
# 6. user instructions message
# 7. Hierarchical agents message
#
#
# - [authentication.md](https://raw.githubusercontent.com/openai/codex/main/docs/authentication.md): Codex Authentication Documentation
# This document provides information on authentication for Codex CLI. It directs users to a separate documentation page for detailed information on Codex CLI authentication. The main concept covered is authentication, and the key technical term is Codex CLI. There are no how-tos or code examples provided in this document. Users can find further information by visiting the provided URL: https://developers.openai.com/codex/auth.
#
# CODE EXAMPLES:
# No code examples are provided in this document.
#
# ADDITIONAL NOTE:
# The document does not contain any additional code examples.
#
# KEY TECHNICAL TERMS:
# 1. Authentication
# 2. Codex CLI
# 3. Codex
# 4. OpenAI
# 5. CLI
#
# Let me know if I can assist with anything else.
#
#
# - [config.md](https://raw.githubusercontent.com/openai/codex/main/docs/config.md): Codex Configuration and Technical Documentation
# This document provides an overview of Codex configuration, setup, and technical details. It covers basic and advanced configuration instructions, connecting to MCP servers, MCP tool approvals, and app connectors. The document also discusses notification settings, JSON schema, SQLite state DB, custom CA certificates, and other technical aspects. Key configuration files and environment variables are mentioned, such as `~/.codex/config.toml`, `CODEX_CA_CERTIFICATE`, and `SSL_CERT_FILE`. The document provides code examples, including a TOML configuration snippet for MCP server approvals.
#
# ```toml
# [mcp_servers.docs.tools.search]
# approval_mode = "approve"
# ```
#
# The document also mentions other configuration options, such as `plan_mode_reasoning_effort` and `experimental_realtime_start_instructions`. Additionally, it references external documentation and schema files, like `codex-rs/core/config.schema.json`.
#
# KEY TERMS:
#
# 1. MCP servers
# 2. Configuration (basic, advanced, reference)
# 3. App connectors
# 4. Notification settings
# 5. JSON schema
# 6. SQLite state DB
# 7. Custom CA certificates
# 8. Environment variables (CODEX_CA_CERTIFICATE, SSL_CERT_FILE)
# 9. TOML configuration
# 10. Codex components
#
#
# - [example-config.md](https://raw.githubusercontent.com/openai/codex/main/docs/example-config.md): Sample Configuration for OpenAI Codex
# This document provides a reference to a sample configuration file for OpenAI Codex. It guides users to an external documentation page that contains a sample configuration. The main concept here is configuration setup for Codex. There are no how-tos or code snippets provided directly in this document. However, users can find further information and potentially code examples by visiting the provided URL.
#
# CODE EXAMPLES:
# No code examples are directly provided in this document.
# Additional examples might be found in the linked documentation: https://developers.openai.com/codex/config-sample.
#
# KEY TECHNICAL TERMS:
# - OpenAI Codex
# - Configuration file
# - Sample configuration
# - Codex setup
# - Configuration sample
# - OpenAI developers documentation
#
#
# - [exec.md](https://raw.githubusercontent.com/openai/codex/main/docs/exec.md): Non-Interactive Mode Documentation
# This document provides information about non-interactive mode in OpenAI Codex. For more detailed information, users are referred to the official documentation at [https://developers.openai.com/codex/noninteractive](https://developers.openai.com/codex/noninteractive). The document does not provide any specific how-tos or technical details within its content.
#
# No code examples are present in this document.
#
# Key technical terms/topics mentioned include:
# - Non-interactive mode
# - OpenAI Codex
# - Official documentation
#
# Note that there are no additional code examples in the document.
#
# KEY TERMS:
# 1. Non-interactive mode
# 2. OpenAI Codex
# 3. Official documentation
# 4. developers.openai.com
# 5. Codex
#
#
# - [execpolicy.md](https://raw.githubusercontent.com/openai/codex/main/docs/execpolicy.md): Codex Execution Policy Documentation
# This document provides an overview of the execution policy for Codex, a tool developed by OpenAI. The execution policy rules are crucial for understanding how Codex operates and handles various tasks. For a detailed explanation, users can refer to the provided link: https://developers.openai.com/codex/exec-policy. The document does not provide specific implementation details or code snippets within its content. However, it serves as a starting point for users to explore the execution policy in more depth.
#
# CODE EXAMPLES:
# None provided in the document.
#
# KEY TECHNICAL TERMS/ TOPICS:
# 1. Execution policy
# 2. Codex
# 3. OpenAI
# 4. Exec-policy rules
# 5. Documentation
#
#
# - [exit-confirmation-prompt-design.md](https://raw.githubusercontent.com/openai/codex/main/docs/exit-confirmation-prompt-design.md): Exit and Shutdown Flow in Codex Rust TUI
# This document describes the exit, shutdown, and interruption flow in the Codex Rust TUI. It explains the terms, event model, user-triggered quit flows, shutdown completion, and edge cases. The main concepts include **Exit**, **Shutdown**, and **Interrupt**. The document outlines how to handle user-initiated quits, such as Ctrl+C and Ctrl+D, and slash commands like `/quit` and `/exit`. It also covers shutdown completion and suppression.
#
# The event model uses `AppEvent::Exit` with explicit modes like `ExitMode::ShutdownFirst` and `ExitMode::Immediate`. For example, `AppEvent::Exit(ExitMode::ShutdownFirst)` is used for user-initiated quits to ensure cleanup runs.
#
# ```markdown
# - `AppEvent::Exit(ExitMode::ShutdownFirst)`
#   - Prefer this for user-initiated quits so cleanup runs.
# ```
#
# There are additional code examples in the document, including explanations of `BottomPane::on_ctrl_c` and `ChatWidget` implementations.
#
# KEY TERMS:
# 1. Exit
# 2. Shutdown
# 3. Interrupt
# 4. AppEvent
# 5. ExitMode
# 6. ShutdownComplete
# 7. Op::Shutdown
# 8. Op::Interrupt
# 9. Ctrl+C
# 10. Ctrl+D
#
#
# - [getting-started.md](https://raw.githubusercontent.com/openai/codex/main/docs/getting-started.md): Getting Started with Codex CLI Documentation
# This document provides an introduction to getting started with Codex CLI. It offers an overview of Codex CLI features and links to further documentation on running the CLI in interactive mode. The document assumes prior knowledge of Codex CLI and its capabilities. For more detailed information on features and usage, users are directed to the OpenAI developers' documentation.
#
# No code examples are present in this document. However, it mentions that additional information on Codex CLI features can be found in the linked documentation.
#
# KEY TERMS:
# 1. Codex CLI
# 2. OpenAI
# 3. Interactive Mode
# 4. CLI Features
# 5. Documentation
#
#
# - [install.md](https://raw.githubusercontent.com/openai/codex/main/docs/install.md): Installing and Building Codex
# This document provides instructions for installing and building Codex, a project written in Rust. It outlines system requirements, including operating systems, Git, and RAM. The document also explains how to build Codex from source using Cargo, including installing the Rust toolchain and helper tools. Additionally, it covers tracing and verbose logging configurations using the `RUST_LOG` environment variable. The document provides a step-by-step guide on how to clone the repository, build, and run Codex, as well as how to run tests.
#
# ```bash
# # Clone the repository and navigate to the root of the Cargo workspace.
# git clone https://github.com/openai/codex.git
# cd codex/codex-rs
#
# # Build Codex.
# cargo build
#
# # Launch the TUI with a sample prompt.
# cargo run --bin codex -- "explain this codebase to me"
# ```
#
# The document also provides an example of monitoring log messages:
# ```bash
# tail -F ~/.codex/log/codex-tui.log
# ```
# There are additional code examples in the document, including instructions for running tests and configuring logging.
#
# KEY TERMS:
#
# * Codex
# * Rust
# * Cargo
# * DotSlash
# * WSL2
# * RUST_LOG
# * env_logger
# * justfile
# * nextest
# * Rust toolchain
#
#
# - [js_repl.md](https://raw.githubusercontent.com/openai/codex/main/docs/js_repl.md): JavaScript REPL (`js_repl`) Documentation
# The `js_repl` tool runs JavaScript in a persistent Node-backed kernel with top-level `await`. It is disabled by default and can be enabled by setting `js_repl = true` in the feature gate. The tool requires a Node version that meets or exceeds the version specified in `codex-rs/node-version.txt`. Module resolution is done through an ordered search path, and local file imports are supported for relative paths, absolute paths, and `file://` URLs. The tool provides helper APIs, including `codex.tool()` and `codex.emitImage()`, and supports debug logging.
#
# Example usage:
# ```javascript
# await codex.emitImage({ bytes: await page.screenshot({ type: "jpeg", quality: 85 }), mimeType: "image/jpeg", detail: "original" })
# ```
# The document also provides an example of sharing a local image tool result:
# ```javascript
# await codex.emitImage(codex.tool("view_image", { path: "/absolute/path", detail: "original" }))
# ```
# Additional examples include using `codex.tool()` to execute normal Codex tool calls and emitting images with `codex.emitImage()`.
#
# KEY TERMS:
#
# * `js_repl`
# * Node-backed kernel
# * Top-level `await`
# * Module resolution
# * `codex.tool()`
# * `codex.emitImage()`
# * Debug logging
# * `meriyah.umd.min.js` (vendored parser asset)
# * `codex-rs/node-version.txt` (Node version specification)
#
#
# - [license.md](https://raw.githubusercontent.com/openai/codex/main/docs/license.md): License Information for OpenAI Codex Repository
# This document provides information about the licensing terms of the openai/codex repository. The repository is licensed under the Apache-2.0 License, which is a permissive free software license that allows users to freely modify and distribute the software. The license terms can be found in the LICENSE file located in the root of the repository.
#
# No code examples are provided in this document.
#
# Additional information:
# - The document does not contain any code examples.
#
# KEY TERMS:
# 1. Apache-2.0 License
# 2. openai/codex repository
# 3. LICENSE file
# 4. Free software license
# 5. Permissive license
#
#
# - [open-source-fund.md](https://raw.githubusercontent.com/openai/codex/main/docs/open-source-fund.md): Codex Open Source Fund Initiative
# The Codex open source fund is a $1 million initiative supporting open source projects that utilize Codex CLI and other OpenAI models. The fund awards grants of up to $25,000 in API credits, with applications reviewed on a rolling basis. To apply, interested parties can visit the provided link: https://openai.com/form/codex-open-source-fund/. This initiative aims to foster the development of open source projects leveraging OpenAI's technology.
#
# No code examples are present in this document.
#
# KEY TERMS:
# 1. Codex open source fund
# 2. OpenAI models
# 3. Codex CLI
# 4. API credits
# 5. Open source projects
# 6. Grant applications
#
#
# - [sandbox.md](https://raw.githubusercontent.com/openai/codex/main/docs/sandbox.md): Codex Sandbox and Approvals Documentation
# This document provides information on Codex sandboxing and approvals. It directs users to a separate documentation page for detailed information on the topic. The main concept discussed is the sandboxing and approval process for Codex, which is crucial for security and access control. To learn more about how to implement sandboxing and approvals, users are referred to the [Codex security documentation](https://developers.openai.com/codex/security). No specific how-tos or code examples are provided in this document.
#
# CODE EXAMPLES:
# None. The document does not provide any code examples.
#
# KEY TECHNICAL TERMS:
# - Codex
# - Sandbox
# - Approvals
# - Security
# - Sandboxing
# - Codex security documentation
#
#
# - [skills.md](https://raw.githubusercontent.com/openai/codex/main/docs/skills.md): Skills Documentation Reference
# This document provides a brief reference to the skills documentation for the OpenAI Codex repository. It directs users to an external documentation page for detailed information on skills. The document does not provide any specific implementation details, tutorials, or code snippets within its content. However, it assumes that users will find relevant information on the linked page. The main concept revolves around skills in the context of OpenAI Codex, but no further elaboration is given here.
#
# CODE EXAMPLES:
# None directly provided in the document.
#
# ADDITIONAL NOTE: The document does not provide additional code examples.
#
# KEY TECHNICAL TERMS/TOPICS:
# 1. Skills
# 2. OpenAI Codex
# 3. Documentation
# 4. Developers
# 5. Codex Skills
#
#
# - [slash_commands.md](https://raw.githubusercontent.com/openai/codex/main/docs/slash_commands.md): Codex CLI Slash Commands Documentation
# This document provides an overview of the slash commands available in the Codex CLI. It directs users to a separate documentation page for detailed information on using these commands. The main concept covered is the availability of slash commands for interacting with the Codex CLI. There are no specific how-tos or technical terms detailed in this document. The structural element is a simple link to further documentation.
#
# No code examples are provided in this document. However, it mentions that additional information can be found at [this documentation](https://developers.openai.com/codex/cli/slash-commands).
#
# KEY TERMS:
# 1. Codex CLI
# 2. Slash commands
# 3. Codex
# 4. CLI
# 5. OpenAI
#
#
# - [tui-alternate-screen.md](https://raw.githubusercontent.com/openai/codex/main/docs/tui-alternate-screen.md): Codex TUI Alternate Screen Handling in Terminal Multiplexers
# This document explains the design decision behind Codex's alternate screen handling in terminal multiplexers like Zellij. It addresses the conflict between fullscreen TUI behavior and terminal scrollback history preservation. Codex implements a pragmatic workaround with three modes controlled by `tui.alternate_screen` in `config.toml`: `auto`, `always`, and `never`. The `auto` mode detects the terminal multiplexer and disables alternate screen mode in Zellij. The `--no-alt-screen` CLI flag can override the config setting at runtime.
#
# Example usage of `auto` detection:
# ```rust
# let terminal_info = codex_core::terminal::terminal_info();
# !matches!(terminal_info.multiplexer, Some(Multiplexer::Zellij { .. }))
# ```
# Example configuration:
# ```toml
# [tui]
# # Options: auto, always, never
# alternate_screen = "auto"
# ```
# There are additional code examples in the document, including implementation details and related issues.
#
# KEY TERMS:
# 1. Alternate screen buffer
# 2. Terminal multiplexer
# 3. Zellij
# 4. xterm specification
# 5. Scrollback history
# 6. Fullscreen TUI
# 7. Codex TUI
# 8. config.toml
# 9. Multiplexer detection
# 10. Terminal state restoration
#
#
# - [tui-chat-composer.md](https://raw.githubusercontent.com/openai/codex/main/docs/tui-chat-composer.md): Chat Composer State Machine and Paste Behavior Documentation
# This document describes the state machine and paste-related behavior of the `ChatComposer` in the TUI. The `ChatComposer` combines two state machines: UI mode and paste burst detection. The paste burst detector is used to handle rapid sequences of key events that can occur when pasting multi-line content in some terminals. The document explains the high-level state machines, key event routing, history navigation, and submission flow. It also covers the paste burst concepts, event-level behavior, and notable interactions.
#
# The `PasteBurst` logic is used to detect paste-like bursts and buffer them into a single explicit `handle_paste(String)` call. The burst detector is intentionally conservative and only processes "plain" character input. The document provides a cheat sheet for the `PasteBurst` decisions and event-level behavior.
#
# Example:
# ```rust
# // No specific code example is provided in the document
# // but here's a high-level example of how the paste burst detector works
# let mut paste_burst = PasteBurst::new();
# let char_decision = paste_burst.on_plain_char('a', now);
# match char_decision {
#     CharDecision::RetainFirstChar => {
#         // do not insert 'a' into the textarea yet
#     }
#     CharDecision::BeginBufferFromPending => {
#         // append 'a' to the buffer
#     }
#     // ...
# }
# ```
# The document also mentions additional code examples, including tests that pin behavior, such as `non_ascii_burst_handles_newline` and `ascii_burst_treats_enter_as_newline`.
#
# KEY TERMS:
#
# 1. ChatComposer
# 2. PasteBurst
# 3. TUI
# 4. State machine
# 5. Burst detection
# 6. Key event routing
# 7. History navigation
# 8. Submission flow
# 9. ASCII path
# 10. non-ASCII path
#
# Note that the document is quite extensive, and the summary provided is a condensed version of the main points.
#
#
# - [tui-request-user-input.md](https://raw.githubusercontent.com/openai/codex/main/docs/tui-request-user-input.md): Request User Input Overlay (TUI) Documentation
# The Request User Input Overlay (TUI) is a component used to gather answers for `RequestUserInputEvent`. It renders one question at a time, allowing users to select an option or enter freeform notes. When options are present, notes are stored per selected option, and the first option is selected by default. The overlay tracks a small focus state, allowing users to navigate using keyboard shortcuts such as Enter, PageUp/PageDown, and Esc. The layout prioritizes keeping the question and options visible, collapsing notes and footer hints as space shrinks.
#
# No specific code examples are provided in the document.
#
# KEY TERMS:
# 1. RequestUserInputEvent
# 2. TUI overlay
# 3. Focus state
# 4. Option selection
# 5. Freeform notes
# 6. Keyboard shortcuts
# 7. Layout priorities
# 8. Option questions
# 9. Notes input
# 10. User input routing
#
#
# - [tui-stream-chunking-review.md](https://raw.githubusercontent.com/openai/codex/main/docs/tui-stream-chunking-review.md): TUI Stream Chunking Design and Implementation
# This document explains the design and implementation of stream chunking in the TUI (Terminal User Interface) of the openai/codex repository. The main goal of stream chunking is to reduce display lag when a backlog of output builds up, while preserving the existing baseline behavior under normal load. The design involves an adaptive policy that switches between two modes: `Smooth` and `CatchUp`. In `Smooth` mode, one line is drained per baseline commit tick, while in `CatchUp` mode, the current queued backlog is drained per tick. The policy uses hysteresis to prevent oscillation when the load hovers near the thresholds. The implementation consists of several components, including `chunking.rs`, `commit_tick.rs`, `controller.rs`, and `chatwidget.rs`.
#
# The runtime flow involves building a queue snapshot, asking the adaptive policy for a decision, applying the drain plan, and emitting drained `HistoryCell`s and trace logs. The document also provides experimental tuning values and explains the invariants and observability features of the design.
#
# ```rust
# // No specific code example is provided in the document.
# // However, the implementation details can be found in the following files:
# // - codex-rs/tui/src/streaming/chunking.rs
# // - codex-rs/tui/src/streaming/commit_tick.rs
# // - codex-rs/tui/src/streaming/controller.rs
# // - codex-rs/tui/src/chatwidget.rs
# ```
#
# KEY TERMS:
#
# 1. TUI Stream Chunking
# 2. Adaptive Policy
# 3. Smooth Mode
# 4. CatchUp Mode
# 5. Hysteresis
# 6. Queue Snapshot
# 7. Drain Plan
# 8. Commit Tick
# 9. HistoryCell
# 10. Observability
#
# Note that there are no additional code examples provided in the document beyond the file references mentioned above.
#
#
# - [tui-stream-chunking-tuning.md](https://raw.githubusercontent.com/openai/codex/main/docs/tui-stream-chunking-tuning.md): TUI Stream Chunking Tuning Guide for Adaptive Performance
# This guide explains how to tune adaptive stream chunking constants in the `codex-rs/tui` repository to optimize performance without changing the underlying policy shape. It covers the scope, goals, and key constants involved in tuning, including baseline commit cadence, enter/exit thresholds, hysteresis holds, and severe-backlog gates. The guide provides a recommended tuning order, symptom-driven adjustments, and a validation checklist. Key concepts include `Smooth` and `CatchUp` modes, queue-pressure thresholds, and hysteresis windows. The guide is intended for adjusting parameters in `codex-rs/tui/src/streaming/chunking.rs` and `codex-rs/tui/src/app.rs`.
#
# Example constants and their effects:
# ```rust
# // Baseline commit cadence
# COMMIT_ANIMATION_TICK (tui/src/app.rs)
#
# // Enter/exit thresholds
# ENTER_QUEUE_DEPTH_LINES, ENTER_OLDEST_AGE
# EXIT_QUEUE_DEPTH_LINES, EXIT_OLDEST_AGE
# ```
# Additional code examples include tuning parameters for hysteresis holds and severe-backlog gates.
#
# KEY TERMS:
#
# 1. Adaptive stream chunking
# 2. Baseline commit cadence
# 3. CatchUp mode
# 4. Enter/exit thresholds
# 5. Hysteresis holds
# 6. Queue-pressure thresholds
# 7. Severe-backlog gates
# 8. Smooth mode
# 9. Stream chunking tuning
# 10. TUI performance optimization
#
#
# - [tui-stream-chunking-validation.md](https://raw.githubusercontent.com/openai/codex/main/docs/tui-stream-chunking-validation.md): TUI Stream Chunking Validation Process
# This document outlines the process for validating adaptive stream chunking and anti-flap behavior in the Codex TUI. The goal is to verify that display lag is reduced when queue pressure rises and mode transitions remain stable. The validation process involves running Codex with chunking traces enabled, capturing logs, and parsing metrics such as commit ticks, mode transitions, and queue depth. The document also provides an experiment history section, which captures major tuning passes.
#
# To run Codex with chunking traces enabled, use the following command:
# ```bash
# RUST_LOG='codex_tui::streaming::commit_tick=trace,codex_tui=info,codex_core=info,codex_rmcp_client=info' \
#   just codex --enable=responses_websockets
# ```
# Additional code examples include a log capture process and metrics reviewed, but the above command is a key example.
#
# KEY TERMS:
# 1. Adaptive stream chunking
# 2. Anti-flap behavior
# 3. Chunking observability
# 4. Commit ticks
# 5. Mode transitions
# 6. Queue depth
# 7. Rapid re-entry count
# 8. Smooth-mode commit cadence
# 9. Stream chunking mode transition
# 10. TUI Stream Chunking Validation Process
#
#
#  for function: None
# Codex Agent: The openai/codex repository is a project primarily written in Rust that provides a CLI and TUI (Terminal User Interface) for interacting with OpenAI Codex models. The repository includes various components and features such as:
#
# 1. **Codex CLI and TUI**: Tools for interacting with Codex models, including interactive and non-interactive modes, with support for slash commands and chat-based interfaces.
#
# 2. **Configuration and Setup**: Extensive configuration options via TOML files, environment variables, and JSON schemas. It supports connecting to MCP servers, custom CA certificates, and SQLite state databases.
#
# 3. **Authentication and Security**: Authentication mechanisms and sandboxing/approval processes to ensure secure and controlled usage.
#
# 4. **Agents and Skills**: Support for hierarchical agents and skills that extend Codex capabilities.
#
# 5. **JavaScript REPL**: A Node-backed JavaScript REPL with top-level await, module resolution, and helper APIs for emitting images and invoking tools.
#
# 6. **Stream Chunking**: Adaptive stream chunking in the TUI to reduce display lag during output backlogs, with modes like Smooth and CatchUp, and tuning guides for performance optimization.
#
# 7. **Exit and Shutdown Handling**: Robust handling of exit, shutdown, and interrupt events in the TUI, including user-triggered quit flows and cleanup.
#
# 8. **Paste Handling**: State machine for handling paste bursts in the chat composer to improve user input experience.
#
# 9. **Terminal Multiplexer Support**: Handling of alternate screen buffers in terminal multiplexers like Zellij to balance fullscreen TUI behavior and scrollback preservation.
#
# 10. **Open Source and Licensing**: The project is licensed under Apache-2.0 and includes an open source fund initiative supporting projects using Codex CLI.
#
# The repository also contains detailed documentation on installation, usage, configuration, execution policies, and various internal mechanisms to help developers and users effectively utilize and contribute to the Codex CLI and TUI tools.
